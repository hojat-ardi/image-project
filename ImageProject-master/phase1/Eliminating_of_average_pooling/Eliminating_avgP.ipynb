# %% [markdown]
# <a href="https://colab.research.google.com/github/hojat-ardi/image-project/blob/Eliminating_avg/Eliminating_avgP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/hojat-ardi/image-project.git
# Out:
# Cloning into 'image-project'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 52 (delta 12), reused 42 (delta 8), pack-reused 0
# Unpacking objects: 100% (52/52), 24.58 KiB | 1.37 MiB/s, done.

# %%
! python /content/image-project/ImageProject-master/phase1/Eliminating_of_average_pooling/main.py
# Out:
# ==> Preparing data..
# ...
# 100% 170498071/170498071 [00:02<00:00, 76521934.57it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 1s621ms | Tot: 39s694ms | Loss: 3.753 | Acc: 12.240% (6120/50000) 391/391
#  [================================================================>]  Step: 30ms | Tot: 2s990ms | Loss: 2.234 | Acc: 15.860% (1586/10000) 100/100
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 63ms | Tot: 39s584ms | Loss: 2.079 | Acc: 22.724% (11362/50000) 391/391
#  [================================================================>]  Step: 24ms | Tot: 3s938ms | Loss: 1.979 | Acc: 25.510% (2551/10000) 100/100
# Saving..
#
# Epoch: 2
# ...
