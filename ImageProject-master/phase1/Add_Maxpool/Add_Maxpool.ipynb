# %%
# !git clone https://github.com/hojat-ardi/image-project.git
# Out:
# Cloning into 'image-project'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 122 (delta 1), reused 6 (delta 1), pack-reused 111
# Receiving objects: 100% (122/122), 39.75 MiB | 34.82 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# !python /content/image-project/ImageProject-master/phase1/Add_Maxpool/main.py
# Out:
# ==> Preparing data..
# ...
# 100% 170498071/170498071 [00:01<00:00, 102582423.07it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 1s616ms | Tot: 39s242ms | Loss: 3.583 | Acc: 18.876% (9438/50000) 391/391
#  [================================================================>]  Step: 25ms | Tot: 3s78ms | Loss: 1.973 | Acc: 26.450% (2645/10000) 100/100
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 65ms | Tot: 39s179ms | Loss: 1.925 | Acc: 28.384% (14192/50000) 391/391
#  [================================================================>]  Step: 27ms | Tot: 3s158ms | Loss: 1.785 | Acc: 33.410% (3341/10000) 100/100
# Saving..
#
# Epoch: 2
# ...
