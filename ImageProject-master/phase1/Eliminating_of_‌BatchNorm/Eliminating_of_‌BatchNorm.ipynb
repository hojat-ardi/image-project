# %% [markdown]
# <a href="https://colab.research.google.com/github/hojat-ardi/image-project/blob/master/ImageProject-master/phase1/Eliminating_of_%E2%80%8CBatchNorm/Eliminating_of_%E2%80%8CBatchNorm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/hojat-ardi/image-project.git
# Out:
# Cloning into 'image-project'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 140 (delta 9), reused 22 (delta 7), pack-reused 111
# Receiving objects: 100% (140/140), 39.75 MiB | 17.85 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
! python /content/image-project/ImageProject-master/phase1/Eliminating_of_‌BatchNorm/main.py
# Out:
# ==> Preparing data..
# ...
# 100% 170498071/170498071 [00:12<00:00, 13138270.03it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 1s612ms | Tot: 35s732ms | Loss: 1.931 | Acc: 26.900% (13450/50000) 391/391
#  [================================================================>]  Step: 23ms | Tot: 2s885ms | Loss: 1.610 | Acc: 39.550% (3955/10000) 100/100
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 59ms | Tot: 35s381ms | Loss: 1.541 | Acc: 42.902% (21451/50000) 391/391
#  [================================================================>]  Step: 23ms | Tot: 3s7ms | Loss: 1.317 | Acc: 52.660% (5266/10000) 100/100
# Saving..
#
# Epoch: 2
# ...
